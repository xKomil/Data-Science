# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

# %%
df = pd.read_csv('dataset/PJME_hourly.csv')
df.set_index('Datetime')
df.index = pd.to_datetime(df.index)

# %%
df.columns
# Out:
# Index(['Datetime', 'PJME_MW'], dtype='object')

# %%
color_palette = sns.color_palette()

# %%
df.plot(style='', figsize=(15,8), color=color_palette, title='PJME Energy use in MW')
plt.show()

# %%
df.dtypes
# Out:
# Datetime     object
# PJME_MW     float64
# dtype: object

# %%
df.plot(style='', figsize=(15,8), color=color_palette, title='PJME Energy use in MW')
plt.show()

# %% [markdown]
# Train / Test Split

# %%
train = df.loc[df.index < '01-01-2015']
test = df.loc[df.index >= '01-01-2015']

fig, ax = plt.subplots(figsize=(15,8))
train.plot(ax=ax, label='Training Set')
test.plot(ax=ax, label='Test set')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 6
#       4 fig, ax = plt.subplots(figsize=(15,8))
#       5 train.plot(ax=ax, label='Training Set')
# ----> 6 test.plot(ax=ax, label='Test set')
#       7 plt.show()
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1502, in LinePlot._make_plot(self, fig)
#    1501 def _make_plot(self, fig: Figure) -> None:
# -> 1502     if self._is_ts_plot():
#    1503         data = maybe_convert_index(self._get_ax(0), self.data)
#    1505         x = data.index  # dummy, not used
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1495, in LinePlot._is_ts_plot(self)
#    1492 @final
#    1493 def _is_ts_plot(self) -> bool:
#    1494     # this is slightly deceptive
# -> 1495     return not self.x_compat and self.use_index and self._use_dynamic_x()
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1499, in LinePlot._use_dynamic_x(self)
#    1497 @final
#    1498 def _use_dynamic_x(self) -> bool:
# -> 1499     return use_dynamic_x(self._get_ax(0), self.data)
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\plotting\_matplotlib\timeseries.py:262, in use_dynamic_x(ax, data)
#     260 if base <= FreqGroup.FR_DAY.value:
#     261     return x[:1].is_normalized
# --> 262 period = Period(x[0], freq_str)
#     263 assert isinstance(period, Period)
#     264 return period.to_timestamp().tz_localize(x.tz) == x[0]
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\core\indexes\base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
#    5392     # This case is separated from the conditional above to avoid
#    5393     # pessimization com.is_bool_indexer and ndim checks.
#    5394     return self._getitem_slice(key)
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\core\arrays\datetimelike.py:381, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     374 """
#     375 This getitem defers to the underlying array, which by-definition can
#     376 only handle list-likes, slices, and integer scalars
#     377 """
#     378 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     379 # but skip evaluating the Union at runtime for performance
#     380 # (see https://github.com/pandas-dev/pandas/pull/44624)
# --> 381 result = cast("Union[Self, DTScalarOrNaT]", super().__getitem__(key))
#     382 if lib.is_scalar(result):
#     383     return result
#
# File d:\Programowanie\Programy\Python\Lib\site-packages\pandas\core\arrays\_mixins.py:284, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     278 def __getitem__(
#     279     self,
#     280     key: PositionalIndexer2D,
#     281 ) -> Self | Any:
#     282     if lib.is_integer(key):
#     283         # fast-path
# --> 284         result = self._ndarray[key]
#     285         if self.ndim == 1:
#     286             return self._box_func(result)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
